# %%
import pandas as pd
import numpy as np
import pickle
from glob import glob

# %%
def boostrapping_confidence_interval(pred_all, ci):
	""" Boostrapping to get a 95 confidence interval for prediction performance
	
	Params
	------
	pred_all: Numpy array
	ci: confidence interval
	
	Yields
	------
	cor_mean: float 
		middle bound
	lb: float
		lower bound
	ub: float
	upper bound
	
	"""
	import random
	# set random seed
	random.seed(0)
	
	# calculate overall correlation
	cor_mean = ma.corrcoef(ma.masked_invalid(pred_all[:,0]), ma.masked_invalid(pred_all[:,1]))[0,1]
	print("Overall prediction/gold standard correlation is %.4f" % cor_mean)
	# start boostrapping ...
	cor_all = [] 
	for i in range(100):
		pred_new = random.choices(pred_all, k = len(pred_all))
		pred_new = np.array(pred_new)
		cor = ma.corrcoef(ma.masked_invalid(pred_new[:,0]), ma.masked_invalid(pred_new[:,1]))[0,1]
		cor_all.append(cor)
	cor_all = sorted(cor_all)
	
	lb = cor_all[round(100*(0.5-ci*0.5))]
	ub = cor_all[round(100*(0.5+ci*0.5))]
	print("%d%s Confidence interval is: (%.4f, %.4f)" % (int(ci*100), '%', lb, ub))
	
	return cor_mean, lb, ub

# %%
all_p = sorted(glob('./M*/results/performances.csv'))
all_p
# Out:
# ['./M0/results/performances.csv',
#  './M1/results/performances.csv',
#  './M10/results/performances.csv',
#  './M11/results/performances.csv',
#  './M12/results/performances.csv',
#  './M13/results/performances.csv',
#  './M14/results/performances.csv',
#  './M15/results/performances.csv',
#  './M16/results/performances.csv',
#  './M17/results/performances.csv',
#  './M18/results/performances.csv',
#  './M19/results/performances.csv',
#  './M2/results/performances.csv',
#  './M3/results/performances.csv',
#  './M4/results/performances.csv',
#  './M5/results/performances.csv',
#  './M6/results/performances.csv',
#  './M7/results/performances.csv',
#  './M8/results/performances.csv',
#  './M9/results/performances.csv']

# %%
all_df = []
for p in all_p:
    df = pd.read_csv(p)
    #df_rmse = pd.read_csv(p.replace('performances.csv', 'performances_rmse.csv'))
    #df = df.merge(df_rmse, on = ['score','dataset_train','dataset_test'])
    print(df)
    all_df.append(df)
all_df = pd.concat(all_df)
# Out:
#     score            dataset_train             dataset_test  \
# 0     css                  ALMANAC                  ALMANAC
# 1     css                  ALMANAC                    ONEIL
# 2     css                  ALMANAC                  FORCINA
# 3     css                  ALMANAC                  Mathews
# 4     css                    ONEIL                  ALMANAC
# ..    ...                      ...                      ...
# 139     S    ALMANAC_Mathews_ONEIL    ALMANAC_Mathews_ONEIL
# 140     S  ALMANAC_FORCINA_Mathews                    ONEIL
# 141     S  ALMANAC_FORCINA_Mathews  ALMANAC_FORCINA_Mathews
# 142     S    FORCINA_Mathews_ONEIL                  ALMANAC
# 143     S    FORCINA_Mathews_ONEIL    FORCINA_Mathews_ONEIL
#
#                  pearsonr                 ci2.5                 ci97.5  \
# 0      0.8813208257350995    0.8806890844785239     0.8823196462777361
# 1      0.1631367609866463    0.1569491198079668    0.17030359964129596
# 2     0.10010740434063851  0.034692818031933026    0.17060802960977536
# 3    -0.14359723595321527  -0.21775822651412358  -0.041146281891249824
# 4     0.10051921734308347    0.0974609730485647    0.10398374793718035
# ..                    ...                   ...                    ...
# 139    0.7610055948208622    0.7591534179424388     0.7628464447959244
# 140  0.020255453445080767  0.013509543588641393    0.02710796627282451
# 141    0.6583658799794179    0.6558234825962099     0.6612058459686803
# 142   0.03810469495382953   0.03349117586144949   0.043773859091226115
# 143    0.8967875192287565     0.895145088029346      0.898397366579066
#
#                      ci25                  ci75  \
# 0      0.8811163000391884    0.8817357320944187
# 1     0.16156078970029059   0.16562704988409077
# 2     0.08290612938810434   0.12491551861087843
# 3    -0.17525673361332492   -0.1231595123220954
# 4     0.09953815604676548   0.10155798362510374
# ..                    ...                   ...
# 139    0.7603419151387915    0.7618270989316215
# 140   0.01800878550726477    0.0226931077724421
# 141    0.6572944528487957    0.6598329846177521
# 142   0.03662794898535077  0.039639081205106994
# 143    0.8962522462698096    0.8973685045863613
#
#                                    features
# 0    drug_categorical+cell_line_categorical
# 1    drug_categorical+cell_line_categorical
# 2    drug_categorical+cell_line_categorical
# 3    drug_categorical+cell_line_categorical
# 4    drug_categorical+cell_line_categorical
# ..                                      ...
# 139  drug_categorical+cell_line_categorical
# 140  drug_categorical+cell_line_categorical
# 141  drug_categorical+cell_line_categorical
# 142  drug_categorical+cell_line_categorical
# 143  drug_categorical+cell_line_categorical
#
# [144 rows x 9 columns]
#     score            dataset_train             dataset_test  pearsonr  \
# 0     css                  ALMANAC                  ALMANAC  0.881532
# 1     css                  ALMANAC                    ONEIL  0.167851
# 2     css                  ALMANAC                  FORCINA  0.098891
# 3     css                  ALMANAC                  Mathews -0.146469
# 4     css                    ONEIL                  ALMANAC  0.099501
# ..    ...                      ...                      ...       ...
# 139     S    ALMANAC_Mathews_ONEIL    ALMANAC_Mathews_ONEIL  0.759975
# 140     S  ALMANAC_FORCINA_Mathews                    ONEIL  0.003215
# 141     S  ALMANAC_FORCINA_Mathews  ALMANAC_FORCINA_Mathews  0.640646
# 142     S    FORCINA_Mathews_ONEIL                  ALMANAC  0.016674
# 143     S    FORCINA_Mathews_ONEIL    FORCINA_Mathews_ONEIL  0.875172
#
#         ci2.5    ci97.5      ci25      ci75  \
# 0    0.880907  0.882578  0.881315  0.881924
# 1    0.162069  0.174523  0.166184  0.170404
# 2    0.037304  0.170890  0.081719  0.123075
# 3   -0.221927 -0.044701 -0.177451 -0.129073
# 4    0.096370  0.103196  0.098336  0.100420
# ..        ...       ...       ...       ...
# 139  0.758046  0.762042  0.759375  0.760680
# 140 -0.002731  0.010018  0.001172  0.004994
# 141  0.638137  0.643701  0.639535  0.641923
# 142  0.013293  0.020406  0.015563  0.018062
# 143  0.873450  0.877333  0.874613  0.875785
#
#                                               features
# 0    drug_categorical+cell_line_categorical+cancer_...
# 1    drug_categorical+cell_line_categorical+cancer_...
# 2    drug_categorical+cell_line_categorical+cancer_...
# 3    drug_categorical+cell_line_categorical+cancer_...
# 4    drug_categorical+cell_line_categorical+cancer_...
# ..                                                 ...
# 139  drug_categorical+cell_line_categorical+cancer_...
# 140  drug_categorical+cell_line_categorical+cancer_...
# 141  drug_categorical+cell_line_categorical+cancer_...
# 142  drug_categorical+cell_line_categorical+cancer_...
# 143  drug_categorical+cell_line_categorical+cancer_...
#
# [144 rows x 9 columns]
#     score            dataset_train             dataset_test  pearsonr  \
# 0     css                  ALMANAC                  ALMANAC  0.931381
# 1     css                  ALMANAC                    ONEIL  0.733631
# 2     css                  ALMANAC                  FORCINA  0.801448
# 3     css                  ALMANAC                  Mathews  0.695037
# 4     css                    ONEIL                  ALMANAC  0.794951
# ..    ...                      ...                      ...       ...
# 139     S    ALMANAC_Mathews_ONEIL    ALMANAC_Mathews_ONEIL  0.849005
# 140     S  ALMANAC_FORCINA_Mathews                    ONEIL  0.695790
# 141     S  ALMANAC_FORCINA_Mathews  ALMANAC_FORCINA_Mathews  0.803164
# 142     S    FORCINA_Mathews_ONEIL                  ALMANAC  0.400665
# 143     S    FORCINA_Mathews_ONEIL    FORCINA_Mathews_ONEIL  0.914968
#
#         ci2.5    ci97.5      ci25      ci75  \
# 0    0.930884  0.932014  0.931201  0.931644
# 1    0.729947  0.737411  0.732544  0.734730
# 2    0.780240  0.823326  0.794962  0.811320
# 3    0.667014  0.735512  0.678879  0.705492
# 4    0.793563  0.796411  0.794458  0.795511
# ..        ...       ...       ...       ...
# 139  0.847842  0.850350  0.848556  0.849348
# 140  0.692820  0.699637  0.694590  0.696839
# 141  0.801299  0.804907  0.802475  0.803672
# 142  0.396563  0.405192  0.399147  0.402452
# 143  0.913119  0.916691  0.914549  0.915489
#
#                                               features
# 0    drug_categorical+cell_line_categorical+cancer_...
# 1    drug_categorical+cell_line_categorical+cancer_...
# 2    drug_categorical+cell_line_categorical+cancer_...
# 3    drug_categorical+cell_line_categorical+cancer_...
# 4    drug_categorical+cell_line_categorical+cancer_...
# ..                                                 ...
# 139  drug_categorical+cell_line_categorical+cancer_...
# 140  drug_categorical+cell_line_categorical+cancer_...
# 141  drug_categorical+cell_line_categorical+cancer_...
# 142  drug_categorical+cell_line_categorical+cancer_...
# 143  drug_categorical+cell_line_categorical+cancer_...
#
# [144 rows x 9 columns]
#     score            dataset_train             dataset_test  pearsonr  \
# 0     css                  ALMANAC                  ALMANAC  0.943578
# 1     css                  ALMANAC                    ONEIL  0.732365
# 2     css                  ALMANAC                  FORCINA  0.751714
# 3     css                  ALMANAC                  Mathews  0.693456
# 4     css                    ONEIL                  ALMANAC  0.371900
# ..    ...                      ...                      ...       ...
# 139     S    ALMANAC_Mathews_ONEIL    ALMANAC_Mathews_ONEIL  0.869224
# 140     S  ALMANAC_FORCINA_Mathews                    ONEIL  0.728390
# 141     S  ALMANAC_FORCINA_Mathews  ALMANAC_FORCINA_Mathews  0.834516
# 142     S    FORCINA_Mathews_ONEIL                  ALMANAC  0.331131
# 143     S    FORCINA_Mathews_ONEIL    FORCINA_Mathews_ONEIL  0.919467
#
#         ci2.5    ci97.5      ci25      ci75  \
# 0    0.943099  0.944142  0.943389  0.943817
# 1    0.729325  0.735200  0.731214  0.733232
# 2    0.726611  0.776337  0.742660  0.761494
# 3    0.664121  0.724093  0.680174  0.703663
# 4    0.370033  0.374113  0.371080  0.372795
# ..        ...       ...       ...       ...
# 139  0.868107  0.870375  0.868767  0.869566
# 140  0.725893  0.731155  0.727279  0.729261
# 141  0.832984  0.835967  0.833999  0.834999
# 142  0.327168  0.336370  0.329655  0.332713
# 143  0.917652  0.921018  0.919124  0.919941
#
#                                               features
# 0    drug_categorical+cell_line_categorical+cancer_...
# 1    drug_categorical+cell_line_categorical+cancer_...
# 2    drug_categorical+cell_line_categorical+cancer_...
# 3    drug_categorical+cell_line_categorical+cancer_...
# 4    drug_categorical+cell_line_categorical+cancer_...
# ..                                                 ...
# 139  drug_categorical+cell_line_categorical+cancer_...
# 140  drug_categorical+cell_line_categorical+cancer_...
# 141  drug_categorical+cell_line_categorical+cancer_...
# 142  drug_categorical+cell_line_categorical+cancer_...
# 143  drug_categorical+cell_line_categorical+cancer_...
#
# [144 rows x 9 columns]
#     score            dataset_train             dataset_test  pearsonr  \
# 0     css                  ALMANAC                  ALMANAC  0.943522
# 1     css                  ALMANAC                    ONEIL  0.840441
# 2     css                  ALMANAC                  FORCINA  0.774127
# 3     css                  ALMANAC                  Mathews  0.873147
# 4     css                    ONEIL                  ALMANAC  0.877949
# ..    ...                      ...                      ...       ...
# 139     S    ALMANAC_Mathews_ONEIL    ALMANAC_Mathews_ONEIL  0.869946
# 140     S  ALMANAC_FORCINA_Mathews                    ONEIL  0.811649
# 141     S  ALMANAC_FORCINA_Mathews  ALMANAC_FORCINA_Mathews  0.833664
# 142     S    FORCINA_Mathews_ONEIL                  ALMANAC  0.494207
# 143     S    FORCINA_Mathews_ONEIL    FORCINA_Mathews_ONEIL  0.919164
#
#         ci2.5    ci97.5      ci25      ci75  \
# 0    0.943054  0.944017  0.943388  0.943742
# 1    0.838269  0.843486  0.839570  0.841250
# 2    0.749939  0.797414  0.767664  0.783173
# 3    0.858645  0.888871  0.866626  0.877329
# 4    0.877106  0.879107  0.877647  0.878356
# ..        ...       ...       ...       ...
# 139  0.868897  0.871241  0.869462  0.870335
# 140  0.809680  0.814371  0.810649  0.812280
# 141  0.832126  0.835042  0.833101  0.834178
# 142  0.490146  0.498229  0.493065  0.495705
# 143  0.917440  0.920649  0.918780  0.919599
#
#                                               features
# 0    drug_categorical+cell_line_categorical+cancer_...
# 1    drug_categorical+cell_line_categorical+cancer_...
# 2    drug_categorical+cell_line_categorical+cancer_...
# 3    drug_categorical+cell_line_categorical+cancer_...
# 4    drug_categorical+cell_line_categorical+cancer_...
# ..                                                 ...
# 139  drug_categorical+cell_line_categorical+cancer_...
# 140  drug_categorical+cell_line_categorical+cancer_...
# 141  drug_categorical+cell_line_categorical+cancer_...
# 142  drug_categorical+cell_line_categorical+cancer_...
# 143  drug_categorical+cell_line_categorical+cancer_...
#
# [144 rows x 9 columns]
#     score            dataset_train             dataset_test  pearsonr  \
# 0     css                  ALMANAC                  ALMANAC  0.943585
# 1     css                  ALMANAC                    ONEIL  0.826350
# 2     css                  ALMANAC                  FORCINA  0.765662
# 3     css                  ALMANAC                  Mathews  0.843295
# 4     css                    ONEIL                  ALMANAC  0.870740
# ..    ...                      ...                      ...       ...
# 139     S    ALMANAC_Mathews_ONEIL    ALMANAC_Mathews_ONEIL  0.869834
# 140     S  ALMANAC_FORCINA_Mathews                    ONEIL  0.790464
# 141     S  ALMANAC_FORCINA_Mathews  ALMANAC_FORCINA_Mathews  0.835166
# 142     S    FORCINA_Mathews_ONEIL                  ALMANAC  0.505511
# 143     S    FORCINA_Mathews_ONEIL    FORCINA_Mathews_ONEIL  0.918998
#
#         ci2.5    ci97.5      ci25      ci75  \
# 0    0.943121  0.944132  0.943423  0.943799
# 1    0.823989  0.829669  0.825287  0.827226
# 2    0.742048  0.788830  0.758112  0.775021
# 3    0.824984  0.860518  0.837952  0.848988
# 4    0.869790  0.871838  0.870446  0.871180
# ..        ...       ...       ...       ...
# 139  0.868818  0.871010  0.869409  0.870142
# 140  0.788370  0.793719  0.789559  0.791250
# 141  0.833583  0.836503  0.834626  0.835631
# 142  0.501555  0.509718  0.504443  0.506952
# 143  0.917038  0.920640  0.918567  0.919479
#
#                                               features
# 0    drug_categorical+cell_line_categorical+cancer_...
# 1    drug_categorical+cell_line_categorical+cancer_...
# 2    drug_categorical+cell_line_categorical+cancer_...
# 3    drug_categorical+cell_line_categorical+cancer_...
# 4    drug_categorical+cell_line_categorical+cancer_...
# ..                                                 ...
# 139  drug_categorical+cell_line_categorical+cancer_...
# 140  drug_categorical+cell_line_categorical+cancer_...
# 141  drug_categorical+cell_line_categorical+cancer_...
# 142  drug_categorical+cell_line_categorical+cancer_...
# 143  drug_categorical+cell_line_categorical+cancer_...
#
# [144 rows x 9 columns]
#     score            dataset_train             dataset_test  pearsonr  \
# 0     css                  ALMANAC                  ALMANAC  0.942201
# 1     css                  ALMANAC                    ONEIL  0.840353
# 2     css                  ALMANAC                  FORCINA  0.796994
# 3     css                  ALMANAC                  Mathews  0.817687
# 4     css                    ONEIL                  ALMANAC  0.876340
# ..    ...                      ...                      ...       ...
# 139     S    ALMANAC_Mathews_ONEIL    ALMANAC_Mathews_ONEIL  0.866729
# 140     S  ALMANAC_FORCINA_Mathews                    ONEIL  0.819320
# 141     S  ALMANAC_FORCINA_Mathews  ALMANAC_FORCINA_Mathews  0.830847
# 142     S    FORCINA_Mathews_ONEIL                  ALMANAC  0.559467
# 143     S    FORCINA_Mathews_ONEIL    FORCINA_Mathews_ONEIL  0.916969
#
#         ci2.5    ci97.5      ci25      ci75  \
# 0    0.941742  0.942715  0.942077  0.942441
# 1    0.838558  0.843047  0.839507  0.841122
# 2    0.776390  0.818504  0.789911  0.805807
# 3    0.795133  0.847306  0.808029  0.826131
# 4    0.875389  0.877408  0.876077  0.876765
# ..        ...       ...       ...       ...
# 139  0.865687  0.868033  0.866342  0.867068
# 140  0.817301  0.821945  0.818329  0.820172
# 141  0.829282  0.832293  0.830202  0.831337
# 142  0.556459  0.563172  0.558223  0.560842
# 143  0.915269  0.918641  0.916545  0.917405
#
#                                               features
# 0    drug_categorical+cell_line_categorical+cancer_...
# 1    drug_categorical+cell_line_categorical+cancer_...
# 2    drug_categorical+cell_line_categorical+cancer_...
# 3    drug_categorical+cell_line_categorical+cancer_...
# 4    drug_categorical+cell_line_categorical+cancer_...
# ..                                                 ...
# 139  drug_categorical+cell_line_categorical+cancer_...
# 140  drug_categorical+cell_line_categorical+cancer_...
# 141  drug_categorical+cell_line_categorical+cancer_...
# 142  drug_categorical+cell_line_categorical+cancer_...
# 143  drug_categorical+cell_line_categorical+cancer_...
#
# [144 rows x 9 columns]
#     score            dataset_train             dataset_test  pearsonr  \
# 0     css                  ALMANAC                  ALMANAC  0.946252
# 1     css                  ALMANAC                    ONEIL  0.857869
# 2     css                  ALMANAC                  FORCINA  0.786518
# 3     css                  ALMANAC                  Mathews  0.905316
# 4     css                    ONEIL                  ALMANAC  0.885962
# ..    ...                      ...                      ...       ...
# 139     S    ALMANAC_Mathews_ONEIL    ALMANAC_Mathews_ONEIL  0.873068
# 140     S  ALMANAC_FORCINA_Mathews                    ONEIL  0.832757
# 141     S  ALMANAC_FORCINA_Mathews  ALMANAC_FORCINA_Mathews  0.839856
# 142     S    FORCINA_Mathews_ONEIL                  ALMANAC  0.561443
# 143     S    FORCINA_Mathews_ONEIL    FORCINA_Mathews_ONEIL  0.919297
#
#         ci2.5    ci97.5      ci25      ci75  \
# 0    0.945840  0.946796  0.946126  0.946464
# 1    0.855359  0.860838  0.857015  0.858652
# 2    0.764667  0.809080  0.779429  0.795635
# 3    0.895905  0.916997  0.901341  0.909135
# 4    0.885045  0.887064  0.885740  0.886298
# ..        ...       ...       ...       ...
# 139  0.871910  0.874348  0.872659  0.873451
# 140  0.830848  0.835234  0.831840  0.833505
# 141  0.838284  0.841101  0.839232  0.840322
# 142  0.558741  0.565033  0.560217  0.562833
# 143  0.917496  0.920920  0.918890  0.919799
#
#                                               features
# 0    drug_categorical+cell_line_categorical+cancer_...
# 1    drug_categorical+cell_line_categorical+cancer_...
# 2    drug_categorical+cell_line_categorical+cancer_...
# 3    drug_categorical+cell_line_categorical+cancer_...
# 4    drug_categorical+cell_line_categorical+cancer_...
# ..                                                 ...
# 139  drug_categorical+cell_line_categorical+cancer_...
# 140  drug_categorical+cell_line_categorical+cancer_...
# 141  drug_categorical+cell_line_categorical+cancer_...
# 142  drug_categorical+cell_line_categorical+cancer_...
# 143  drug_categorical+cell_line_categorical+cancer_...
#
# [144 rows x 9 columns]
#     score            dataset_train             dataset_test  pearsonr  \
# 0     css                  ALMANAC                  ALMANAC  0.926751
# 1     css                  ALMANAC                    ONEIL  0.850905
# 2     css                  ALMANAC                  FORCINA  0.768874
# 3     css                  ALMANAC                  Mathews  0.896937
# 4     css                    ONEIL                  ALMANAC  0.880213
# ..    ...                      ...                      ...       ...
# 139     S    ALMANAC_Mathews_ONEIL    ALMANAC_Mathews_ONEIL  0.825667
# 140     S  ALMANAC_FORCINA_Mathews                    ONEIL  0.801941
# 141     S  ALMANAC_FORCINA_Mathews  ALMANAC_FORCINA_Mathews  0.772947
# 142     S    FORCINA_Mathews_ONEIL                  ALMANAC  0.582015
# 143     S    FORCINA_Mathews_ONEIL    FORCINA_Mathews_ONEIL  0.901485
#
#         ci2.5    ci97.5      ci25      ci75  \
# 0    0.926238  0.927455  0.926510  0.927051
# 1    0.848670  0.854284  0.849944  0.851738
# 2    0.746104  0.792290  0.760185  0.778675
# 3    0.885483  0.909531  0.892553  0.902160
# 4    0.879233  0.881187  0.879985  0.880544
# ..        ...       ...       ...       ...
# 139  0.824385  0.827334  0.825097  0.826118
# 140  0.799698  0.804354  0.801085  0.802711
# 141  0.771162  0.774879  0.772209  0.773709
# 142  0.579458  0.585193  0.581138  0.583336
# 143  0.899612  0.903283  0.900867  0.901936
#
#                                            features
# 0    drc_intp_linear+drc_intp_lagrange+drc_intp_4PL
# 1    drc_intp_linear+drc_intp_lagrange+drc_intp_4PL
# 2    drc_intp_linear+drc_intp_lagrange+drc_intp_4PL
# 3    drc_intp_linear+drc_intp_lagrange+drc_intp_4PL
# 4    drc_intp_linear+drc_intp_lagrange+drc_intp_4PL
# ..                                              ...
# 139  drc_intp_linear+drc_intp_lagrange+drc_intp_4PL
# 140  drc_intp_linear+drc_intp_lagrange+drc_intp_4PL
# 141  drc_intp_linear+drc_intp_lagrange+drc_intp_4PL
# 142  drc_intp_linear+drc_intp_lagrange+drc_intp_4PL
# 143  drc_intp_linear+drc_intp_lagrange+drc_intp_4PL
#
# [144 rows x 9 columns]
#     score            dataset_train             dataset_test  pearsonr  \
# 0     css                  ALMANAC                  ALMANAC  0.928485
# 1     css                  ALMANAC                    ONEIL  0.851054
# 2     css                  ALMANAC                  FORCINA  0.756155
# 3     css                  ALMANAC                  Mathews  0.897372
# 4     css                    ONEIL                  ALMANAC  0.883855
# ..    ...                      ...                      ...       ...
# 139     S    ALMANAC_Mathews_ONEIL    ALMANAC_Mathews_ONEIL  0.835680
# 140     S  ALMANAC_FORCINA_Mathews                    ONEIL  0.828338
# 141     S  ALMANAC_FORCINA_Mathews  ALMANAC_FORCINA_Mathews  0.788662
# 142     S    FORCINA_Mathews_ONEIL                  ALMANAC  0.603534
# 143     S    FORCINA_Mathews_ONEIL    FORCINA_Mathews_ONEIL  0.902366
#
#         ci2.5    ci97.5      ci25      ci75  \
# 0    0.927938  0.929203  0.928243  0.928733
# 1    0.848629  0.854138  0.850266  0.851927
# 2    0.730909  0.780693  0.747145  0.766468
# 3    0.887476  0.911772  0.893145  0.902350
# 4    0.882968  0.884815  0.883595  0.884179
# ..        ...       ...       ...       ...
# 139  0.834334  0.837377  0.835138  0.836129
# 140  0.825931  0.831100  0.827598  0.829152
# 141  0.786753  0.790356  0.788051  0.789329
# 142  0.600750  0.606424  0.602656  0.604509
# 143  0.900457  0.904355  0.901848  0.902821
#
#                                               features
# 0    monotherapy_ic50+monotherapy_ri+drc_intp_linea...
# 1    monotherapy_ic50+monotherapy_ri+drc_intp_linea...
# 2    monotherapy_ic50+monotherapy_ri+drc_intp_linea...
# 3    monotherapy_ic50+monotherapy_ri+drc_intp_linea...
# 4    monotherapy_ic50+monotherapy_ri+drc_intp_linea...
# ..                                                 ...
# 139  monotherapy_ic50+monotherapy_ri+drc_intp_linea...
# 140  monotherapy_ic50+monotherapy_ri+drc_intp_linea...
# 141  monotherapy_ic50+monotherapy_ri+drc_intp_linea...
# 142  monotherapy_ic50+monotherapy_ri+drc_intp_linea...
# 143  monotherapy_ic50+monotherapy_ri+drc_intp_linea...
#
# [144 rows x 9 columns]
#     score            dataset_train             dataset_test  pearsonr  \
# 0     css                  ALMANAC                  ALMANAC  0.930089
# 1     css                  ALMANAC                    ONEIL  0.835890
# 2     css                  ALMANAC                  FORCINA  0.797537
# 3     css                  ALMANAC                  Mathews  0.878040
# 4     css                    ONEIL                  ALMANAC  0.469151
# ..    ...                      ...                      ...       ...
# 139     S    ALMANAC_Mathews_ONEIL    ALMANAC_Mathews_ONEIL  0.833487
# 140     S  ALMANAC_FORCINA_Mathews                    ONEIL  0.813434
# 141     S  ALMANAC_FORCINA_Mathews  ALMANAC_FORCINA_Mathews  0.782410
# 142     S    FORCINA_Mathews_ONEIL                  ALMANAC  0.566752
# 143     S    FORCINA_Mathews_ONEIL    FORCINA_Mathews_ONEIL  0.905832
#
#         ci2.5    ci97.5      ci25      ci75  \
# 0    0.929583  0.930773  0.929862  0.930345
# 1    0.833455  0.839338  0.835110  0.836708
# 2    0.777329  0.819094  0.790396  0.806945
# 3    0.865020  0.889518  0.872882  0.883120
# 4    0.467009  0.471711  0.468366  0.470014
# ..        ...       ...       ...       ...
# 139  0.832204  0.835012  0.832941  0.833824
# 140  0.811499  0.816060  0.812631  0.814313
# 141  0.780527  0.784131  0.781712  0.783124
# 142  0.564312  0.570247  0.565676  0.568022
# 143  0.903834  0.907644  0.905289  0.906260
#
#                                               features
# 0    drc_baseline+drc_intp_linear+drc_intp_lagrange...
# 1    drc_baseline+drc_intp_linear+drc_intp_lagrange...
# 2    drc_baseline+drc_intp_linear+drc_intp_lagrange...
# 3    drc_baseline+drc_intp_linear+drc_intp_lagrange...
# 4    drc_baseline+drc_intp_linear+drc_intp_lagrange...
# ..                                                 ...
# 139  drc_baseline+drc_intp_linear+drc_intp_lagrange...
# 140  drc_baseline+drc_intp_linear+drc_intp_lagrange...
# 141  drc_baseline+drc_intp_linear+drc_intp_lagrange...
# 142  drc_baseline+drc_intp_linear+drc_intp_lagrange...
# 143  drc_baseline+drc_intp_linear+drc_intp_lagrange...
#
# [144 rows x 9 columns]
#     score            dataset_train             dataset_test  pearsonr  \
# 0     css                  ALMANAC                  ALMANAC  0.930599
# 1     css                  ALMANAC                    ONEIL  0.839190
# 2     css                  ALMANAC                  FORCINA  0.780656
# 3     css                  ALMANAC                  Mathews  0.855777
# 4     css                    ONEIL                  ALMANAC  0.476002
# ..    ...                      ...                      ...       ...
# 139     S    ALMANAC_Mathews_ONEIL    ALMANAC_Mathews_ONEIL  0.841362
# 140     S  ALMANAC_FORCINA_Mathews                    ONEIL  0.829710
# 141     S  ALMANAC_FORCINA_Mathews  ALMANAC_FORCINA_Mathews  0.795209
# 142     S    FORCINA_Mathews_ONEIL                  ALMANAC  0.576756
# 143     S    FORCINA_Mathews_ONEIL    FORCINA_Mathews_ONEIL  0.906672
#
#         ci2.5    ci97.5      ci25      ci75  \
# 0    0.930085  0.931284  0.930370  0.930839
# 1    0.836681  0.842096  0.838286  0.840143
# 2    0.758631  0.802805  0.773186  0.790723
# 3    0.841350  0.868533  0.848621  0.860906
# 4    0.474049  0.478725  0.475128  0.476970
# ..        ...       ...       ...       ...
# 139  0.840030  0.842834  0.840848  0.841744
# 140  0.827355  0.832776  0.828931  0.830500
# 141  0.793211  0.796898  0.794550  0.795818
# 142  0.574533  0.580254  0.575798  0.578189
# 143  0.904711  0.908424  0.906177  0.907152
#
#                                               features
# 0    monotherapy_ic50+monotherapy_ri+drc_baseline+d...
# 1    monotherapy_ic50+monotherapy_ri+drc_baseline+d...
# 2    monotherapy_ic50+monotherapy_ri+drc_baseline+d...
# 3    monotherapy_ic50+monotherapy_ri+drc_baseline+d...
# 4    monotherapy_ic50+monotherapy_ri+drc_baseline+d...
# ..                                                 ...
# 139  monotherapy_ic50+monotherapy_ri+drc_baseline+d...
# 140  monotherapy_ic50+monotherapy_ri+drc_baseline+d...
# 141  monotherapy_ic50+monotherapy_ri+drc_baseline+d...
# 142  monotherapy_ic50+monotherapy_ri+drc_baseline+d...
# 143  monotherapy_ic50+monotherapy_ri+drc_baseline+d...
#
# [144 rows x 9 columns]
#     score            dataset_train             dataset_test  \
# 0     css                  ALMANAC                  ALMANAC
# 1     css                  ALMANAC                    ONEIL
# 2     css                  ALMANAC                  FORCINA
# 3     css                  ALMANAC                  Mathews
# 4     css                    ONEIL                  ALMANAC
# ..    ...                      ...                      ...
# 139     S    ALMANAC_Mathews_ONEIL    ALMANAC_Mathews_ONEIL
# 140     S  ALMANAC_FORCINA_Mathews                    ONEIL
# 141     S  ALMANAC_FORCINA_Mathews  ALMANAC_FORCINA_Mathews
# 142     S    FORCINA_Mathews_ONEIL                  ALMANAC
# 143     S    FORCINA_Mathews_ONEIL    FORCINA_Mathews_ONEIL
#
#                    pearsonr                   ci2.5                  ci97.5  \
# 0        0.2711768162238244     0.26756642676910347      0.2753598217470982
# 1       0.25421950097224966     0.24922951678255187     0.26103169439610263
# 2    -9.734658599332134e-17  -2.249039729877355e-16  2.6916534493407607e-16
# 3       0.04845856873622125   -0.019297652496579193      0.1004684367761312
# 4       0.12862301187302713     0.12585990870803082     0.13340332852614262
# ..                      ...                     ...                     ...
# 139       0.335690940057037     0.33321274499908404     0.33931148928346705
# 140      0.3269971870403362      0.3211675629975458      0.3330330278430091
# 141      0.2573245984333496     0.25374846614400737     0.26067182020638546
# 142     0.11347297734394408     0.10960194605865692     0.11678130614916395
# 143      0.5721999466845651       0.567283084685045      0.5761418523544654
#
#                        ci25                 ci75          features
# 0       0.26989898237913973   0.2723548446771171  monotherapy_ic50
# 1       0.25229237568955126  0.25771152278784276  monotherapy_ic50
# 2    -9.407440905378842e-17  9.2423997906564e-17  monotherapy_ic50
# 3      0.034641561259429354  0.07138631138799235  monotherapy_ic50
# 4       0.12759496742660104   0.1299698476560744  monotherapy_ic50
# ..                      ...                  ...               ...
# 139      0.3347860934592882   0.3366998799758164  monotherapy_ic50
# 140      0.3252641029747749   0.3286989117473998  monotherapy_ic50
# 141      0.2558011798631182   0.2583329294585876  monotherapy_ic50
# 142     0.11217947116833697  0.11454278394298249  monotherapy_ic50
# 143      0.5709351717556155   0.5736026125167091  monotherapy_ic50
#
# [144 rows x 9 columns]
#     score            dataset_train             dataset_test  pearsonr  \
# 0     css                  ALMANAC                  ALMANAC  0.845719
# 1     css                  ALMANAC                    ONEIL  0.742397
# 2     css                  ALMANAC                  FORCINA  0.740516
# 3     css                  ALMANAC                  Mathews  0.710416
# 4     css                    ONEIL                  ALMANAC  0.814630
# ..    ...                      ...                      ...       ...
# 139     S    ALMANAC_Mathews_ONEIL    ALMANAC_Mathews_ONEIL  0.599868
# 140     S  ALMANAC_FORCINA_Mathews                    ONEIL  0.733327
# 141     S  ALMANAC_FORCINA_Mathews  ALMANAC_FORCINA_Mathews  0.479543
# 142     S    FORCINA_Mathews_ONEIL                  ALMANAC  0.387543
# 143     S    FORCINA_Mathews_ONEIL    FORCINA_Mathews_ONEIL  0.776457
#
#         ci2.5    ci97.5      ci25      ci75        features
# 0    0.844651  0.847234  0.845356  0.846249  monotherapy_ri
# 1    0.739251  0.745747  0.741138  0.743258  monotherapy_ri
# 2    0.716133  0.763978  0.732151  0.752411  monotherapy_ri
# 3    0.682179  0.748064  0.694968  0.720088  monotherapy_ri
# 4    0.813221  0.816130  0.814365  0.815149  monotherapy_ri
# ..        ...       ...       ...       ...             ...
# 139  0.597759  0.602753  0.599210  0.600850  monotherapy_ri
# 140  0.730869  0.736485  0.732163  0.734078  monotherapy_ri
# 141  0.475680  0.483307  0.478124  0.481065  monotherapy_ri
# 142  0.383151  0.393529  0.386274  0.389366  monotherapy_ri
# 143  0.773656  0.778730  0.775234  0.777352  monotherapy_ri
#
# [144 rows x 9 columns]
#     score            dataset_train             dataset_test  pearsonr  \
# 0     css                  ALMANAC                  ALMANAC  0.875631
# 1     css                  ALMANAC                    ONEIL  0.748747
# 2     css                  ALMANAC                  FORCINA  0.779920
# 3     css                  ALMANAC                  Mathews  0.727211
# 4     css                    ONEIL                  ALMANAC  0.808779
# ..    ...                      ...                      ...       ...
# 139     S    ALMANAC_Mathews_ONEIL    ALMANAC_Mathews_ONEIL  0.692785
# 140     S  ALMANAC_FORCINA_Mathews                    ONEIL  0.733790
# 141     S  ALMANAC_FORCINA_Mathews  ALMANAC_FORCINA_Mathews  0.606185
# 142     S    FORCINA_Mathews_ONEIL                  ALMANAC  0.368864
# 143     S    FORCINA_Mathews_ONEIL    FORCINA_Mathews_ONEIL  0.865110
#
#         ci2.5    ci97.5      ci25      ci75                         features
# 0    0.874648  0.876883  0.875306  0.876110  monotherapy_ri+monotherapy_ic50
# 1    0.745686  0.752182  0.747393  0.749899  monotherapy_ri+monotherapy_ic50
# 2    0.757666  0.801138  0.771678  0.790720  monotherapy_ri+monotherapy_ic50
# 3    0.699681  0.763516  0.709888  0.734498  monotherapy_ri+monotherapy_ic50
# 4    0.807482  0.810256  0.808386  0.809279  monotherapy_ri+monotherapy_ic50
# ..        ...       ...       ...       ...                              ...
# 139  0.690918  0.695105  0.692132  0.693476  monotherapy_ri+monotherapy_ic50
# 140  0.730963  0.736794  0.732888  0.734327  monotherapy_ri+monotherapy_ic50
# 141  0.602866  0.609366  0.604894  0.607382  monotherapy_ri+monotherapy_ic50
# 142  0.364273  0.373236  0.367260  0.370711  monotherapy_ri+monotherapy_ic50
# 143  0.863214  0.866770  0.864366  0.865735  monotherapy_ri+monotherapy_ic50
#
# [144 rows x 9 columns]
#     score            dataset_train             dataset_test  pearsonr  \
# 0     css                  ALMANAC                  ALMANAC  0.920458
# 1     css                  ALMANAC                    ONEIL  0.672470
# 2     css                  ALMANAC                  FORCINA  0.517092
# 3     css                  ALMANAC                  Mathews  0.557788
# 4     css                    ONEIL                  ALMANAC  0.267645
# ..    ...                      ...                      ...       ...
# 139     S    ALMANAC_Mathews_ONEIL    ALMANAC_Mathews_ONEIL  0.808497
# 140     S  ALMANAC_FORCINA_Mathews                    ONEIL  0.679132
# 141     S  ALMANAC_FORCINA_Mathews  ALMANAC_FORCINA_Mathews  0.746375
# 142     S    FORCINA_Mathews_ONEIL                  ALMANAC  0.299681
# 143     S    FORCINA_Mathews_ONEIL    FORCINA_Mathews_ONEIL  0.902355
#
#         ci2.5    ci97.5      ci25      ci75      features
# 0    0.919838  0.921295  0.920194  0.920742  drc_baseline
# 1    0.669353  0.675674  0.670849  0.673539  drc_baseline
# 2    0.485345  0.548229  0.503794  0.527667  drc_baseline
# 3    0.513413  0.612665  0.542731  0.570708  drc_baseline
# 4    0.264865  0.271149  0.266799  0.268588  drc_baseline
# ..        ...       ...       ...       ...           ...
# 139  0.807017  0.810475  0.807953  0.808941  drc_baseline
# 140  0.675793  0.683173  0.677637  0.679991  drc_baseline
# 141  0.743986  0.749102  0.745618  0.747139  drc_baseline
# 142  0.296716  0.305229  0.298549  0.301369  drc_baseline
# 143  0.900350  0.904093  0.901787  0.902935  drc_baseline
#
# [144 rows x 9 columns]
#     score            dataset_train             dataset_test  pearsonr  \
# 0     css                  ALMANAC                  ALMANAC  0.918127
# 1     css                  ALMANAC                    ONEIL  0.838445
# 2     css                  ALMANAC                  FORCINA  0.793858
# 3     css                  ALMANAC                  Mathews  0.787777
# 4     css                    ONEIL                  ALMANAC  0.881219
# ..    ...                      ...                      ...       ...
# 139     S    ALMANAC_Mathews_ONEIL    ALMANAC_Mathews_ONEIL  0.802627
# 140     S  ALMANAC_FORCINA_Mathews                    ONEIL  0.773790
# 141     S  ALMANAC_FORCINA_Mathews  ALMANAC_FORCINA_Mathews  0.739743
# 142     S    FORCINA_Mathews_ONEIL                  ALMANAC  0.463775
# 143     S    FORCINA_Mathews_ONEIL    FORCINA_Mathews_ONEIL  0.898611
#
#         ci2.5    ci97.5      ci25      ci75         features
# 0    0.917501  0.918985  0.917861  0.918420  drc_intp_linear
# 1    0.836467  0.841074  0.837542  0.839188  drc_intp_linear
# 2    0.772081  0.814321  0.786024  0.803164  drc_intp_linear
# 3    0.763426  0.812170  0.777342  0.795352  drc_intp_linear
# 4    0.880184  0.882249  0.880902  0.881596  drc_intp_linear
# ..        ...       ...       ...       ...              ...
# 139  0.801453  0.804298  0.802061  0.803047  drc_intp_linear
# 140  0.771485  0.776904  0.772780  0.774572  drc_intp_linear
# 141  0.737526  0.742001  0.739093  0.740549  drc_intp_linear
# 142  0.460120  0.468746  0.462566  0.465594  drc_intp_linear
# 143  0.896720  0.900515  0.897955  0.899140  drc_intp_linear
#
# [144 rows x 9 columns]
#     score            dataset_train             dataset_test  pearsonr  \
# 0     css                  ALMANAC                  ALMANAC  0.917747
# 1     css                  ALMANAC                    ONEIL  0.813755
# 2     css                  ALMANAC                  FORCINA  0.773511
# 3     css                  ALMANAC                  Mathews  0.726383
# 4     css                    ONEIL                  ALMANAC  0.857730
# ..    ...                      ...                      ...       ...
# 139     S    ALMANAC_Mathews_ONEIL    ALMANAC_Mathews_ONEIL  0.798276
# 140     S  ALMANAC_FORCINA_Mathews                    ONEIL  0.625489
# 141     S  ALMANAC_FORCINA_Mathews  ALMANAC_FORCINA_Mathews  0.736996
# 142     S    FORCINA_Mathews_ONEIL                  ALMANAC  0.470701
# 143     S    FORCINA_Mathews_ONEIL    FORCINA_Mathews_ONEIL  0.895668
#
#         ci2.5    ci97.5      ci25      ci75           features
# 0    0.917154  0.918578  0.917477  0.918013  drc_intp_lagrange
# 1    0.811143  0.817085  0.812682  0.814741  drc_intp_lagrange
# 2    0.751661  0.794852  0.765735  0.783176  drc_intp_lagrange
# 3    0.697162  0.753767  0.717071  0.737551  drc_intp_lagrange
# 4    0.856648  0.858899  0.857350  0.858124  drc_intp_lagrange
# ..        ...       ...       ...       ...                ...
# 139  0.796979  0.800004  0.797677  0.798777  drc_intp_lagrange
# 140  0.622737  0.630036  0.624324  0.626987  drc_intp_lagrange
# 141  0.734923  0.739259  0.736306  0.737958  drc_intp_lagrange
# 142  0.467436  0.474856  0.469578  0.472447  drc_intp_lagrange
# 143  0.893527  0.897561  0.895153  0.896167  drc_intp_lagrange
#
# [144 rows x 9 columns]
#     score            dataset_train             dataset_test  pearsonr  \
# 0     css                  ALMANAC                  ALMANAC  0.911221
# 1     css                  ALMANAC                    ONEIL  0.836877
# 2     css                  ALMANAC                  FORCINA  0.762111
# 3     css                  ALMANAC                  Mathews  0.724779
# 4     css                    ONEIL                  ALMANAC  0.866896
# ..    ...                      ...                      ...       ...
# 139     S    ALMANAC_Mathews_ONEIL    ALMANAC_Mathews_ONEIL  0.779576
# 140     S  ALMANAC_FORCINA_Mathews                    ONEIL  0.807736
# 141     S  ALMANAC_FORCINA_Mathews  ALMANAC_FORCINA_Mathews  0.723351
# 142     S    FORCINA_Mathews_ONEIL                  ALMANAC  0.558402
# 143     S    FORCINA_Mathews_ONEIL    FORCINA_Mathews_ONEIL  0.886185
#
#         ci2.5    ci97.5      ci25      ci75      features
# 0    0.910565  0.912101  0.911046  0.911583  drc_intp_4PL
# 1    0.834323  0.839919  0.836133  0.837893  drc_intp_4PL
# 2    0.739420  0.785990  0.754097  0.771118  drc_intp_4PL
# 3    0.693714  0.762943  0.712906  0.731361  drc_intp_4PL
# 4    0.865852  0.867804  0.866647  0.867298  drc_intp_4PL
# ..        ...       ...       ...       ...           ...
# 139  0.778086  0.781674  0.779002  0.780157  drc_intp_4PL
# 140  0.805726  0.810352  0.806717  0.808563  drc_intp_4PL
# 141  0.721595  0.725742  0.722487  0.724181  drc_intp_4PL
# 142  0.555375  0.562556  0.557114  0.559480  drc_intp_4PL
# 143  0.884211  0.888415  0.885336  0.886623  drc_intp_4PL
#
# [144 rows x 9 columns]
#     score            dataset_train             dataset_test  pearsonr  \
# 0     css                  ALMANAC                  ALMANAC  0.923448
# 1     css                  ALMANAC                    ONEIL  0.843479
# 2     css                  ALMANAC                  FORCINA  0.741207
# 3     css                  ALMANAC                  Mathews  0.847936
# 4     css                    ONEIL                  ALMANAC  0.882270
# ..    ...                      ...                      ...       ...
# 139     S    ALMANAC_Mathews_ONEIL    ALMANAC_Mathews_ONEIL  0.823965
# 140     S  ALMANAC_FORCINA_Mathews                    ONEIL  0.822681
# 141     S  ALMANAC_FORCINA_Mathews  ALMANAC_FORCINA_Mathews  0.771060
# 142     S    FORCINA_Mathews_ONEIL                  ALMANAC  0.538867
# 143     S    FORCINA_Mathews_ONEIL    FORCINA_Mathews_ONEIL  0.901728
#
#         ci2.5    ci97.5      ci25      ci75  \
# 0    0.922853  0.924317  0.923208  0.923734
# 1    0.841315  0.846122  0.842567  0.844222
# 2    0.715158  0.768327  0.730197  0.751084
# 3    0.830381  0.864653  0.840578  0.853825
# 4    0.881342  0.883284  0.881974  0.882610
# ..        ...       ...       ...       ...
# 139  0.822683  0.825676  0.823358  0.824386
# 140  0.820606  0.825381  0.821815  0.823493
# 141  0.769091  0.772982  0.770314  0.771828
# 142  0.535165  0.542841  0.537612  0.540256
# 143  0.899836  0.903485  0.901187  0.902296
#
#                                             features
# 0    monotherapy_ic50+monotherapy_ri+drc_intp_linear
# 1    monotherapy_ic50+monotherapy_ri+drc_intp_linear
# 2    monotherapy_ic50+monotherapy_ri+drc_intp_linear
# 3    monotherapy_ic50+monotherapy_ri+drc_intp_linear
# 4    monotherapy_ic50+monotherapy_ri+drc_intp_linear
# ..                                               ...
# 139  monotherapy_ic50+monotherapy_ri+drc_intp_linear
# 140  monotherapy_ic50+monotherapy_ri+drc_intp_linear
# 141  monotherapy_ic50+monotherapy_ri+drc_intp_linear
# 142  monotherapy_ic50+monotherapy_ri+drc_intp_linear
# 143  monotherapy_ic50+monotherapy_ri+drc_intp_linear
#
# [144 rows x 9 columns]

# %%
df
# Out:
#     score            dataset_train             dataset_test  pearsonr  \
# 0     css                  ALMANAC                  ALMANAC  0.923448
# 1     css                  ALMANAC                    ONEIL  0.843479
# 2     css                  ALMANAC                  FORCINA  0.741207
# 3     css                  ALMANAC                  Mathews  0.847936
# 4     css                    ONEIL                  ALMANAC  0.882270
# ..    ...                      ...                      ...       ...
# 139     S    ALMANAC_Mathews_ONEIL    ALMANAC_Mathews_ONEIL  0.823965
# 140     S  ALMANAC_FORCINA_Mathews                    ONEIL  0.822681
# 141     S  ALMANAC_FORCINA_Mathews  ALMANAC_FORCINA_Mathews  0.771060
# 142     S    FORCINA_Mathews_ONEIL                  ALMANAC  0.538867
# 143     S    FORCINA_Mathews_ONEIL    FORCINA_Mathews_ONEIL  0.901728
#
#         ci2.5    ci97.5      ci25      ci75  \
# 0    0.922853  0.924317  0.923208  0.923734
# 1    0.841315  0.846122  0.842567  0.844222
# 2    0.715158  0.768327  0.730197  0.751084
# 3    0.830381  0.864653  0.840578  0.853825
# 4    0.881342  0.883284  0.881974  0.882610
# ..        ...       ...       ...       ...
# 139  0.822683  0.825676  0.823358  0.824386
# 140  0.820606  0.825381  0.821815  0.823493
# 141  0.769091  0.772982  0.770314  0.771828
# 142  0.535165  0.542841  0.537612  0.540256
# 143  0.899836  0.903485  0.901187  0.902296
#
#                                             features
# 0    monotherapy_ic50+monotherapy_ri+drc_intp_linear
# 1    monotherapy_ic50+monotherapy_ri+drc_intp_linear
# 2    monotherapy_ic50+monotherapy_ri+drc_intp_linear
# 3    monotherapy_ic50+monotherapy_ri+drc_intp_linear
# 4    monotherapy_ic50+monotherapy_ri+drc_intp_linear
# ..                                               ...
# 139  monotherapy_ic50+monotherapy_ri+drc_intp_linear
# 140  monotherapy_ic50+monotherapy_ri+drc_intp_linear
# 141  monotherapy_ic50+monotherapy_ri+drc_intp_linear
# 142  monotherapy_ic50+monotherapy_ri+drc_intp_linear
# 143  monotherapy_ic50+monotherapy_ri+drc_intp_linear
#
# [144 rows x 9 columns]

# %%
all_df.to_csv('all_performances.csv', index = False)
